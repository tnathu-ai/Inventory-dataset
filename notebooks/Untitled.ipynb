# %%
# Install a conda package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install missingno


# work with data in tabular representation
from datetime import time
import pandas as pd
# round the data in the correlation matrix
import numpy as np
import os
import glob


# Modules for data visualization
import seaborn as sns
import missingno as msno

# run a python function file 
# %run ../src/cleaning/function.py

# ignore DeprecationWarning Error Messages
import warnings
warnings.filterwarnings('ignore')

# %%
# set the path of the external data from the third party source - Kaggle
external_data_path = os.path.join(os.path.pardir, 'data','external')

df = os.path.join(external_data_path, 'DataCoSupplyChainDataset.csv')

# import dataset
df = pd.read_csv(df, delimiter=',', skipinitialspace = True)

print("The shape of the data is (row, column):", str(df.shape))
df.head(3)
# Out:
# The shape of the data is (row, column): (180519, 53)
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
#
#   Customer Country Customer Email Customer Fname  Customer Id Customer Lname  \
# ...

# %%
# df['Product Name'].unique()

# %%
# set the path of the external data from the third party source - Kaggle
external_data_path = os.path.join(os.path.pardir, 'data','external')

df = os.path.join(external_data_path, 'DescriptionDataCoSupplyChain.csv')

# import dataset
df = pd.read_csv(df, delimiter=',', skipinitialspace = True)

print("The shape of the data is (row, column):", str(df.shape))
df.head(3)
# Out:
# The shape of the data is (row, column): (52, 2)
#                           FIELDS  \
# 0                           Type
# 1  Days for shipping (real)
# 2  Days for shipment (scheduled)
#
#                                          DESCRIPTION
# 0                        :  Type of transaction made
# 1   :  Actual shipping days of the purchased product
# 2  :  Days of scheduled delivery of the purchased...

# %%
# set the path of the external data from the third party source - Kaggle
external_data_path = os.path.join(os.path.pardir, 'data','external')

df = os.path.join(external_data_path, 'tokenized_access_logs.csv')

# import dataset
df = pd.read_csv(df, delimiter=',', skipinitialspace = True)

print("The shape of the data is (row, column):", str(df.shape))
df.head(3)
# Out:
# The shape of the data is (row, column): (469977, 8)
#                                    Product             Category  \
# 0  adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1    The North Face Women's Recon Backpack   hunting & shooting
# 2   adidas Kids' RG III Mid Football Cleat       featured shops
#
#             Date Month  Hour Department             ip  \
# 0  9/1/2017 6:00   Sep     6   fitness    37.97.182.65
# 1  9/1/2017 6:00   Sep     6  fan shop    206.56.112.1
# 2  9/1/2017 6:00   Sep     6   apparel   215.143.180.0
#
#                                                  url
# 0  /department/fitness/category/baseball%20&%20so...
# 1  /department/fan%20shop/category/hunting%20&%20...
# 2  /department/apparel/category/featured%20shops/...
